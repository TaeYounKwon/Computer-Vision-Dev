# %% [markdown]
# # Basic Crawling 및 이미지 다운로드

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os
import urllib.request
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 폴더 생성

# %%
def create_folder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print("error : Creating directory ... " + directory)

# %%
keywords = "funny cat"
create_folder('./'+keywords+'_img_download')

# %% [markdown]
# #### chromedriver실행

# %%
# 크롬창이 함수를 종료할 때마다 닫히지 않게 해주는 옵션
options = webdriver.ChromeOptions()
options.add_experimental_option("detach", True)


chromedriver_path = "./chromedriver.exe"

driver = webdriver.Chrome(chromedriver_path, options=options)
driver.implicitly_wait(3)

# %% [markdown]
# ### 키워드 입력 및 selenium 실행

# %%
driver.get("https://www.google.co.kr/imghp?h1=ko")
position = driver.get_window_position()
x = position.get('x')
y = position.get('y')
print("x: "+ str(x) + "y: " + str(y))
# Out:
# x: 3188y: 213

# %%
driver.maximize_window()
# driver.fullscreen_window()

# %% [markdown]
# - input -> /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input
# - button -> /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button

# %%
keyword = driver.find_element_by_xpath(
    '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
keyword.send_keys(keywords)
keyword.send_keys(Keys.RETURN)

# %% [markdown]
# ### 스크롤 내리기

# %%
print('Scroll Down .......')
elem = driver.find_element_by_tag_name('body')
for i in range(60):
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)

try:
    # //*[@id="islmp"]/div/div/div/div[2]/div[1]/div[2]/div[2]/input
    driver.find_element_by_xpath(
        '//*[@id="islmp"]/div/div/div/div[2]/div[1]/div[2]/div[2]/input').click()
    for i in range(60):
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.2)
except:
    pass
# Out:
# Scroll Down .......
# funny cat img found:  400

# %% [markdown]
# ### 이미지 개수 파악
#
# - 구글 이미지 검색 결과의 각 썸네일 이미지 class name은 img.rg_i.Q4LuWd이다.
#
# - 따라서 driver.find_elements_by_css_selector를 통해 해당 class name을 가진 모든 요소를 images로 불러온다.
#
# - 또한, 구조를 살펴보면 각 이미지는 src에 해당 이미지 링크를 가지고 있다. get_attribute를 통해 links라는 빈 리스트에 각 link들을 넣어주었다.

# %%
links = []
images = driver.find_elements_by_css_selector("img.rg_i.Q4LuWd")

for image in images:
    if image.get_attribute('src') != None:
        links.append(image.get_attribute('src'))

print(keywords + " img found: ", len(links))
time.sleep(2)
# Out:
# funny cat img found:  400

# %% [markdown]
# ### 데이터 다운로드
#
# - links에 들어있는 link를 urllib.request를 통해 하나씩 요청하고, 해당 이미지들을 '키워드_number'의 형태로 위에서 만들어준 폴더에 저장하도록 한다.

# %%
for index, i in enumerate(links):
    url = i
    start = time.time()
    urllib.request.urlretrieve(url, './' + keywords + "_img_download/" + keywords + "_" + str(index) + ".jpg")
    print(str(index) + "/" + str(len(links)) + " " + keywords +
          " Downloaded ------ : ", str(time.time() - start)[:5] + 'sec')

print(keywords + "Download Finished !!")
# Out:
# 0/400 funny cat Downloaded ------ :  0.0sec
# 1/400 funny cat Downloaded ------ :  0.0sec
# 2/400 funny cat Downloaded ------ :  0.000sec
# 3/400 funny cat Downloaded ------ :  0.001sec
# 4/400 funny cat Downloaded ------ :  0.000sec
# 5/400 funny cat Downloaded ------ :  0.0sec
# 6/400 funny cat Downloaded ------ :  0.000sec
# 7/400 funny cat Downloaded ------ :  0.000sec
# 8/400 funny cat Downloaded ------ :  0.0sec
# 9/400 funny cat Downloaded ------ :  0.000sec
# 10/400 funny cat Downloaded ------ :  0.001sec
# 11/400 funny cat Downloaded ------ :  0.001sec
# 12/400 funny cat Downloaded ------ :  0.0sec
# 13/400 funny cat Downloaded ------ :  0.001sec
# 14/400 funny cat Downloaded ------ :  0.001sec
# 15/400 funny cat Downloaded ------ :  0.0sec
# 16/400 funny cat Downloaded ------ :  0.000sec
# 17/400 funny cat Downloaded ------ :  0.000sec
# 18/400 funny cat Downloaded ------ :  0.000sec
# 19/400 funny cat Downloaded ------ :  0.0sec
# 20/400 funny cat Downloaded ------ :  0.065sec
# 21/400 funny cat Downloaded ------ :  0.055sec
# 22/400 funny cat Downloaded ------ :  0.043sec
# 23/400 funny cat Downloaded ------ :  0.044sec
# 24/400 funny cat Downloaded ------ :  0.046sec
# 25/400 funny cat Downloaded ------ :  0.048sec
# 26/400 funny cat Downloaded ------ :  0.054sec
# 27/400 funny cat Downloaded ------ :  0.048sec
# 28/400 funny cat Downloaded ------ :  0.051sec
# 29/400 funny cat Downloaded ------ :  0.047sec
# 30/400 funny cat Downloaded ------ :  0.046sec
# 31/400 funny cat Downloaded ------ :  0.044sec
# 32/400 funny cat Downloaded ------ :  0.053sec
# 33/400 funny cat Downloaded ------ :  0.043sec
# 34/400 funny cat Downloaded ------ :  0.045sec
# 35/400 funny cat Downloaded ------ :  0.050sec
# 36/400 funny cat Downloaded ------ :  0.046sec
# 37/400 funny cat Downloaded ------ :  0.045sec
# 38/400 funny cat Downloaded ------ :  0.043sec
# 39/400 funny cat Downloaded ------ :  0.045sec
# 40/400 funny cat Downloaded ------ :  0.046sec
# 41/400 funny cat Downloaded ------ :  0.053sec
# 42/400 funny cat Downloaded ------ :  0.050sec
# 43/400 funny cat Downloaded ------ :  0.052sec
# 44/400 funny cat Downloaded ------ :  0.075sec
# 45/400 funny cat Downloaded ------ :  0.050sec
# 46/400 funny cat Downloaded ------ :  0.065sec
# 47/400 funny cat Downloaded ------ :  0.051sec
# 48/400 funny cat Downloaded ------ :  0.054sec
# 49/400 funny cat Downloaded ------ :  0.051sec
# 50/400 funny cat Downloaded ------ :  0.049sec
# 51/400 funny cat Downloaded ------ :  0.050sec
# 52/400 funny cat Downloaded ------ :  0.050sec
# 53/400 funny cat Downloaded ------ :  0.051sec
# 54/400 funny cat Downloaded ------ :  0.049sec
# 55/400 funny cat Downloaded ------ :  0.056sec
# 56/400 funny cat Downloaded ------ :  0.051sec
# 57/400 funny cat Downloaded ------ :  0.052sec
# 58/400 funny cat Downloaded ------ :  0.054sec
# 59/400 funny cat Downloaded ------ :  0.047sec
# 60/400 funny cat Downloaded ------ :  0.049sec
# 61/400 funny cat Downloaded ------ :  0.057sec
# 62/400 funny cat Downloaded ------ :  0.050sec
# 63/400 funny cat Downloaded ------ :  0.049sec
# 64/400 funny cat Downloaded ------ :  0.048sec
# 65/400 funny cat Downloaded ------ :  0.047sec
# 66/400 funny cat Downloaded ------ :  0.053sec
# 67/400 funny cat Downloaded ------ :  0.048sec
# 68/400 funny cat Downloaded ------ :  0.051sec
# 69/400 funny cat Downloaded ------ :  0.064sec
# 70/400 funny cat Downloaded ------ :  0.054sec
# 71/400 funny cat Downloaded ------ :  0.050sec
# 72/400 funny cat Downloaded ------ :  0.053sec
# 73/400 funny cat Downloaded ------ :  0.051sec
# 74/400 funny cat Downloaded ------ :  0.050sec
# 75/400 funny cat Downloaded ------ :  0.057sec
# 76/400 funny cat Downloaded ------ :  0.051sec
# 77/400 funny cat Downloaded ------ :  0.051sec
# 78/400 funny cat Downloaded ------ :  0.060sec
# 79/400 funny cat Downloaded ------ :  0.057sec
# 80/400 funny cat Downloaded ------ :  0.066sec
# 81/400 funny cat Downloaded ------ :  0.052sec
# 82/400 funny cat Downloaded ------ :  0.051sec
# 83/400 funny cat Downloaded ------ :  0.052sec
# 84/400 funny cat Downloaded ------ :  0.046sec
# 85/400 funny cat Downloaded ------ :  0.047sec
# 86/400 funny cat Downloaded ------ :  0.055sec
# 87/400 funny cat Downloaded ------ :  0.046sec
# 88/400 funny cat Downloaded ------ :  0.046sec
# 89/400 funny cat Downloaded ------ :  0.047sec
# 90/400 funny cat Downloaded ------ :  0.051sec
# 91/400 funny cat Downloaded ------ :  0.045sec
# 92/400 funny cat Downloaded ------ :  0.047sec
# 93/400 funny cat Downloaded ------ :  0.053sec
# 94/400 funny cat Downloaded ------ :  0.046sec
# 95/400 funny cat Downloaded ------ :  0.045sec
# 96/400 funny cat Downloaded ------ :  0.044sec
# 97/400 funny cat Downloaded ------ :  0.048sec
# 98/400 funny cat Downloaded ------ :  0.049sec
# 99/400 funny cat Downloaded ------ :  0.047sec
# 100/400 funny cat Downloaded ------ :  0.050sec
# 101/400 funny cat Downloaded ------ :  0.064sec
# 102/400 funny cat Downloaded ------ :  0.053sec
# 103/400 funny cat Downloaded ------ :  0.051sec
# 104/400 funny cat Downloaded ------ :  0.047sec
# 105/400 funny cat Downloaded ------ :  0.050sec
# 106/400 funny cat Downloaded ------ :  0.082sec
# 107/400 funny cat Downloaded ------ :  0.050sec
# 108/400 funny cat Downloaded ------ :  0.045sec
# 109/400 funny cat Downloaded ------ :  0.044sec
# 110/400 funny cat Downloaded ------ :  0.044sec
# 111/400 funny cat Downloaded ------ :  0.046sec
# 112/400 funny cat Downloaded ------ :  0.047sec
# 113/400 funny cat Downloaded ------ :  0.050sec
# 114/400 funny cat Downloaded ------ :  0.047sec
# 115/400 funny cat Downloaded ------ :  0.046sec
# 116/400 funny cat Downloaded ------ :  0.048sec
# 117/400 funny cat Downloaded ------ :  0.053sec
# 118/400 funny cat Downloaded ------ :  0.046sec
# 119/400 funny cat Downloaded ------ :  0.052sec
# 120/400 funny cat Downloaded ------ :  0.050sec
# 121/400 funny cat Downloaded ------ :  0.046sec
# 122/400 funny cat Downloaded ------ :  0.048sec
# 123/400 funny cat Downloaded ------ :  0.048sec
# 124/400 funny cat Downloaded ------ :  0.059sec
# 125/400 funny cat Downloaded ------ :  0.045sec
# 126/400 funny cat Downloaded ------ :  0.045sec
# 127/400 funny cat Downloaded ------ :  0.053sec
# 128/400 funny cat Downloaded ------ :  0.044sec
# 129/400 funny cat Downloaded ------ :  0.049sec
# 130/400 funny cat Downloaded ------ :  0.054sec
# 131/400 funny cat Downloaded ------ :  0.055sec
# 132/400 funny cat Downloaded ------ :  0.045sec
# 133/400 funny cat Downloaded ------ :  0.053sec
# 134/400 funny cat Downloaded ------ :  0.046sec
# 135/400 funny cat Downloaded ------ :  0.049sec
# 136/400 funny cat Downloaded ------ :  0.058sec
# 137/400 funny cat Downloaded ------ :  0.048sec
# 138/400 funny cat Downloaded ------ :  0.050sec
# 139/400 funny cat Downloaded ------ :  0.043sec
# 140/400 funny cat Downloaded ------ :  0.055sec
# 141/400 funny cat Downloaded ------ :  0.048sec
# 142/400 funny cat Downloaded ------ :  0.046sec
# 143/400 funny cat Downloaded ------ :  0.045sec
# 144/400 funny cat Downloaded ------ :  0.046sec
# 145/400 funny cat Downloaded ------ :  0.045sec
# 146/400 funny cat Downloaded ------ :  0.048sec
# 147/400 funny cat Downloaded ------ :  0.045sec
# 148/400 funny cat Downloaded ------ :  0.058sec
# 149/400 funny cat Downloaded ------ :  0.080sec
# 150/400 funny cat Downloaded ------ :  0.051sec
# 151/400 funny cat Downloaded ------ :  0.051sec
# 152/400 funny cat Downloaded ------ :  0.058sec
# 153/400 funny cat Downloaded ------ :  0.052sec
# 154/400 funny cat Downloaded ------ :  0.052sec
# 155/400 funny cat Downloaded ------ :  0.056sec
# 156/400 funny cat Downloaded ------ :  0.056sec
# 157/400 funny cat Downloaded ------ :  0.051sec
# 158/400 funny cat Downloaded ------ :  0.051sec
# 159/400 funny cat Downloaded ------ :  0.049sec
# 160/400 funny cat Downloaded ------ :  0.051sec
# 161/400 funny cat Downloaded ------ :  0.056sec
# 162/400 funny cat Downloaded ------ :  0.048sec
# 163/400 funny cat Downloaded ------ :  0.052sec
# 164/400 funny cat Downloaded ------ :  0.051sec
# 165/400 funny cat Downloaded ------ :  0.053sec
# 166/400 funny cat Downloaded ------ :  0.048sec
# 167/400 funny cat Downloaded ------ :  0.047sec
# 168/400 funny cat Downloaded ------ :  0.045sec
# 169/400 funny cat Downloaded ------ :  0.055sec
# 170/400 funny cat Downloaded ------ :  0.058sec
# 171/400 funny cat Downloaded ------ :  0.047sec
# 172/400 funny cat Downloaded ------ :  0.050sec
# 173/400 funny cat Downloaded ------ :  0.045sec
# 174/400 funny cat Downloaded ------ :  0.046sec
# 175/400 funny cat Downloaded ------ :  0.047sec
# 176/400 funny cat Downloaded ------ :  0.053sec
# 177/400 funny cat Downloaded ------ :  0.048sec
# 178/400 funny cat Downloaded ------ :  0.047sec
# 179/400 funny cat Downloaded ------ :  0.051sec
# 180/400 funny cat Downloaded ------ :  0.091sec
# 181/400 funny cat Downloaded ------ :  0.045sec
# 182/400 funny cat Downloaded ------ :  0.046sec
# 183/400 funny cat Downloaded ------ :  0.045sec
# 184/400 funny cat Downloaded ------ :  0.046sec
# 185/400 funny cat Downloaded ------ :  0.052sec
# 186/400 funny cat Downloaded ------ :  0.045sec
# 187/400 funny cat Downloaded ------ :  0.048sec
# 188/400 funny cat Downloaded ------ :  0.057sec
# 189/400 funny cat Downloaded ------ :  0.051sec
# 190/400 funny cat Downloaded ------ :  0.049sec
# 191/400 funny cat Downloaded ------ :  0.050sec
# 192/400 funny cat Downloaded ------ :  0.110sec
# 193/400 funny cat Downloaded ------ :  0.048sec
# 194/400 funny cat Downloaded ------ :  0.048sec
# 195/400 funny cat Downloaded ------ :  0.048sec
# 196/400 funny cat Downloaded ------ :  0.048sec
# 197/400 funny cat Downloaded ------ :  0.049sec
# 198/400 funny cat Downloaded ------ :  0.052sec
# 199/400 funny cat Downloaded ------ :  0.046sec
# 200/400 funny cat Downloaded ------ :  0.048sec
# 201/400 funny cat Downloaded ------ :  0.045sec
# 202/400 funny cat Downloaded ------ :  0.047sec
# 203/400 funny cat Downloaded ------ :  0.044sec
# 204/400 funny cat Downloaded ------ :  0.047sec
# 205/400 funny cat Downloaded ------ :  0.045sec
# 206/400 funny cat Downloaded ------ :  0.046sec
# 207/400 funny cat Downloaded ------ :  0.046sec
# 208/400 funny cat Downloaded ------ :  0.052sec
# 209/400 funny cat Downloaded ------ :  0.044sec
# 210/400 funny cat Downloaded ------ :  0.048sec
# 211/400 funny cat Downloaded ------ :  0.045sec
# 212/400 funny cat Downloaded ------ :  0.047sec
# 213/400 funny cat Downloaded ------ :  0.046sec
# 214/400 funny cat Downloaded ------ :  0.093sec
# 215/400 funny cat Downloaded ------ :  0.045sec
# 216/400 funny cat Downloaded ------ :  0.051sec
# 217/400 funny cat Downloaded ------ :  0.043sec
# 218/400 funny cat Downloaded ------ :  0.047sec
# 219/400 funny cat Downloaded ------ :  0.044sec
# 220/400 funny cat Downloaded ------ :  0.041sec
# 221/400 funny cat Downloaded ------ :  0.049sec
# 222/400 funny cat Downloaded ------ :  0.053sec
# 223/400 funny cat Downloaded ------ :  0.051sec
# 224/400 funny cat Downloaded ------ :  0.045sec
# 225/400 funny cat Downloaded ------ :  0.054sec
# 226/400 funny cat Downloaded ------ :  0.046sec
# 227/400 funny cat Downloaded ------ :  0.046sec
# 228/400 funny cat Downloaded ------ :  0.048sec
# 229/400 funny cat Downloaded ------ :  0.046sec
# 230/400 funny cat Downloaded ------ :  0.050sec
# 231/400 funny cat Downloaded ------ :  0.051sec
# 232/400 funny cat Downloaded ------ :  0.049sec
# 233/400 funny cat Downloaded ------ :  0.051sec
# 234/400 funny cat Downloaded ------ :  0.056sec
# 235/400 funny cat Downloaded ------ :  0.047sec
# 236/400 funny cat Downloaded ------ :  0.046sec
# 237/400 funny cat Downloaded ------ :  0.044sec
# 238/400 funny cat Downloaded ------ :  0.045sec
# 239/400 funny cat Downloaded ------ :  0.042sec
# 240/400 funny cat Downloaded ------ :  0.042sec
# 241/400 funny cat Downloaded ------ :  0.044sec
# 242/400 funny cat Downloaded ------ :  0.047sec
# 243/400 funny cat Downloaded ------ :  0.046sec
# 244/400 funny cat Downloaded ------ :  0.046sec
# 245/400 funny cat Downloaded ------ :  0.043sec
# 246/400 funny cat Downloaded ------ :  0.089sec
# 247/400 funny cat Downloaded ------ :  0.051sec
# 248/400 funny cat Downloaded ------ :  0.045sec
# 249/400 funny cat Downloaded ------ :  0.044sec
# 250/400 funny cat Downloaded ------ :  0.047sec
# 251/400 funny cat Downloaded ------ :  0.045sec
# 252/400 funny cat Downloaded ------ :  0.047sec
# 253/400 funny cat Downloaded ------ :  0.052sec
# 254/400 funny cat Downloaded ------ :  0.046sec
# 255/400 funny cat Downloaded ------ :  0.052sec
# 256/400 funny cat Downloaded ------ :  0.088sec
# 257/400 funny cat Downloaded ------ :  0.047sec
# 258/400 funny cat Downloaded ------ :  0.049sec
# 259/400 funny cat Downloaded ------ :  0.049sec
# 260/400 funny cat Downloaded ------ :  0.051sec
# 261/400 funny cat Downloaded ------ :  0.058sec
# 262/400 funny cat Downloaded ------ :  0.054sec
# 263/400 funny cat Downloaded ------ :  0.055sec
# 264/400 funny cat Downloaded ------ :  0.057sec
# 265/400 funny cat Downloaded ------ :  0.048sec
# 266/400 funny cat Downloaded ------ :  0.050sec
# 267/400 funny cat Downloaded ------ :  0.052sec
# 268/400 funny cat Downloaded ------ :  0.057sec
# 269/400 funny cat Downloaded ------ :  0.054sec
# 270/400 funny cat Downloaded ------ :  0.048sec
# 271/400 funny cat Downloaded ------ :  0.050sec
# 272/400 funny cat Downloaded ------ :  0.052sec
# 273/400 funny cat Downloaded ------ :  0.052sec
# 274/400 funny cat Downloaded ------ :  0.057sec
# 275/400 funny cat Downloaded ------ :  0.046sec
# 276/400 funny cat Downloaded ------ :  0.046sec
# 277/400 funny cat Downloaded ------ :  0.048sec
# 278/400 funny cat Downloaded ------ :  0.047sec
# 279/400 funny cat Downloaded ------ :  0.052sec
# 280/400 funny cat Downloaded ------ :  0.045sec
# 281/400 funny cat Downloaded ------ :  0.047sec
# 282/400 funny cat Downloaded ------ :  0.050sec
# 283/400 funny cat Downloaded ------ :  0.050sec
# 284/400 funny cat Downloaded ------ :  0.110sec
# 285/400 funny cat Downloaded ------ :  0.047sec
# 286/400 funny cat Downloaded ------ :  0.043sec
# 287/400 funny cat Downloaded ------ :  0.047sec
# 288/400 funny cat Downloaded ------ :  0.047sec
# 289/400 funny cat Downloaded ------ :  0.052sec
# 290/400 funny cat Downloaded ------ :  0.047sec
# 291/400 funny cat Downloaded ------ :  0.043sec
# 292/400 funny cat Downloaded ------ :  0.044sec
# 293/400 funny cat Downloaded ------ :  0.041sec
# 294/400 funny cat Downloaded ------ :  0.046sec
# 295/400 funny cat Downloaded ------ :  0.045sec
# 296/400 funny cat Downloaded ------ :  0.043sec
# 297/400 funny cat Downloaded ------ :  0.048sec
# 298/400 funny cat Downloaded ------ :  0.046sec
# 299/400 funny cat Downloaded ------ :  0.045sec
# 300/400 funny cat Downloaded ------ :  0.046sec
# 301/400 funny cat Downloaded ------ :  0.048sec
# 302/400 funny cat Downloaded ------ :  0.044sec
# 303/400 funny cat Downloaded ------ :  0.052sec
# 304/400 funny cat Downloaded ------ :  0.046sec
# 305/400 funny cat Downloaded ------ :  0.044sec
# 306/400 funny cat Downloaded ------ :  0.044sec
# 307/400 funny cat Downloaded ------ :  0.046sec
# 308/400 funny cat Downloaded ------ :  0.043sec
# 309/400 funny cat Downloaded ------ :  0.047sec
# 310/400 funny cat Downloaded ------ :  0.046sec
# 311/400 funny cat Downloaded ------ :  0.045sec
# 312/400 funny cat Downloaded ------ :  0.048sec
# 313/400 funny cat Downloaded ------ :  0.043sec
# 314/400 funny cat Downloaded ------ :  0.046sec
# 315/400 funny cat Downloaded ------ :  0.053sec
# 316/400 funny cat Downloaded ------ :  0.046sec
# 317/400 funny cat Downloaded ------ :  0.045sec
# 318/400 funny cat Downloaded ------ :  0.043sec
# 319/400 funny cat Downloaded ------ :  0.046sec
# 320/400 funny cat Downloaded ------ :  0.045sec
# 321/400 funny cat Downloaded ------ :  0.058sec
# 322/400 funny cat Downloaded ------ :  0.043sec
# 323/400 funny cat Downloaded ------ :  0.041sec
# 324/400 funny cat Downloaded ------ :  0.048sec
# 325/400 funny cat Downloaded ------ :  0.043sec
# 326/400 funny cat Downloaded ------ :  0.041sec
# 327/400 funny cat Downloaded ------ :  0.043sec
# 328/400 funny cat Downloaded ------ :  0.043sec
# 329/400 funny cat Downloaded ------ :  0.045sec
# 330/400 funny cat Downloaded ------ :  0.047sec
# 331/400 funny cat Downloaded ------ :  0.043sec
# 332/400 funny cat Downloaded ------ :  0.051sec
# 333/400 funny cat Downloaded ------ :  0.042sec
# 334/400 funny cat Downloaded ------ :  0.044sec
# 335/400 funny cat Downloaded ------ :  0.045sec
# 336/400 funny cat Downloaded ------ :  0.049sec
# 337/400 funny cat Downloaded ------ :  0.043sec
# 338/400 funny cat Downloaded ------ :  0.043sec
# 339/400 funny cat Downloaded ------ :  0.049sec
# 340/400 funny cat Downloaded ------ :  0.044sec
# 341/400 funny cat Downloaded ------ :  0.043sec
# 342/400 funny cat Downloaded ------ :  0.044sec
# 343/400 funny cat Downloaded ------ :  0.045sec
# 344/400 funny cat Downloaded ------ :  0.045sec
# 345/400 funny cat Downloaded ------ :  0.042sec
# 346/400 funny cat Downloaded ------ :  0.044sec
# 347/400 funny cat Downloaded ------ :  0.043sec
# 348/400 funny cat Downloaded ------ :  0.041sec
# 349/400 funny cat Downloaded ------ :  0.059sec
# 350/400 funny cat Downloaded ------ :  0.042sec
# 351/400 funny cat Downloaded ------ :  0.044sec
# 352/400 funny cat Downloaded ------ :  0.044sec
# 353/400 funny cat Downloaded ------ :  0.043sec
# 354/400 funny cat Downloaded ------ :  0.043sec
# 355/400 funny cat Downloaded ------ :  0.041sec
# 356/400 funny cat Downloaded ------ :  0.043sec
# 357/400 funny cat Downloaded ------ :  0.040sec
# 358/400 funny cat Downloaded ------ :  0.048sec
# 359/400 funny cat Downloaded ------ :  0.046sec
# 360/400 funny cat Downloaded ------ :  0.052sec
# 361/400 funny cat Downloaded ------ :  0.047sec
# 362/400 funny cat Downloaded ------ :  0.053sec
# 363/400 funny cat Downloaded ------ :  0.044sec
# 364/400 funny cat Downloaded ------ :  0.041sec
# 365/400 funny cat Downloaded ------ :  0.046sec
# 366/400 funny cat Downloaded ------ :  0.045sec
# 367/400 funny cat Downloaded ------ :  0.042sec
# 368/400 funny cat Downloaded ------ :  0.057sec
# 369/400 funny cat Downloaded ------ :  0.056sec
# 370/400 funny cat Downloaded ------ :  0.046sec
# 371/400 funny cat Downloaded ------ :  0.046sec
# 372/400 funny cat Downloaded ------ :  0.059sec
# 373/400 funny cat Downloaded ------ :  0.053sec
# 374/400 funny cat Downloaded ------ :  0.052sec
# 375/400 funny cat Downloaded ------ :  0.046sec
# 376/400 funny cat Downloaded ------ :  0.047sec
# 377/400 funny cat Downloaded ------ :  0.045sec
# 378/400 funny cat Downloaded ------ :  0.045sec
# 379/400 funny cat Downloaded ------ :  0.049sec
# 380/400 funny cat Downloaded ------ :  0.048sec
# 381/400 funny cat Downloaded ------ :  0.047sec
# 382/400 funny cat Downloaded ------ :  0.049sec
# 383/400 funny cat Downloaded ------ :  0.052sec
# 384/400 funny cat Downloaded ------ :  0.047sec
# 385/400 funny cat Downloaded ------ :  0.048sec
# 386/400 funny cat Downloaded ------ :  0.047sec
# 387/400 funny cat Downloaded ------ :  0.043sec
# 388/400 funny cat Downloaded ------ :  0.054sec
# 389/400 funny cat Downloaded ------ :  0.046sec
# 390/400 funny cat Downloaded ------ :  0.042sec
# 391/400 funny cat Downloaded ------ :  0.055sec
# 392/400 funny cat Downloaded ------ :  0.049sec
# 393/400 funny cat Downloaded ------ :  0.054sec
# 394/400 funny cat Downloaded ------ :  0.042sec
# 395/400 funny cat Downloaded ------ :  0.046sec
# 396/400 funny cat Downloaded ------ :  0.042sec
# 397/400 funny cat Downloaded ------ :  0.042sec
# 398/400 funny cat Downloaded ------ :  0.046sec
# 399/400 funny cat Downloaded ------ :  0.045sec
# funny catDownload Finished !!

# %%
driver.quit()
